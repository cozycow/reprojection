# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from utils import *

# %%
nx, ny = 1024, 1024
xc, yc = 511.5, 511.5
Rsun = 512

view = View(nx, ny, xc, yc, Rsun, 0, 80, 0, rsun_arc=0. * 3600)

# %%
V = view.velocity()

plt.figure(figsize=(10,10))
plt.imshow(V)
#plt.plot(V[:,200])

# %%
mu = view.mu()

plt.figure(figsize=(10,10))
plt.imshow(mu)
