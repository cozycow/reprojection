# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from sft import *

# %%
d = 10
dt = 0.1

x = np.arange(-127.5, 128)
xi = np.arange(-128, 128.5)

#x = np.sin(x / 128 * np.pi / 2) * 128
#xi = np.sin(xi / 128 * np.pi / 2) * 128

vi = 1 #np.ones_like(xi)
#vi = np.cos(xi / 128 * np.pi / 2)

y = np.exp(-x ** 2 / 2 / 16 ** 2)
y0 = y.copy()

for _ in range(1000):
    #y = advect(y, vi, dt, xi=xi, boundary='mirror', hires=True)
    y = diffuse(y, d, dt, xi=xi)

plt.figure(figsize=(10,8))
plt.plot(x, y0)
plt.plot(x, y)

# %%
y.shape
# Out:
# (256,)
