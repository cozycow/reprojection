# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
from utils import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
#files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*blos_202505*'))
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/202604/blos/*'))
files
# Out:
# ['/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T014503_V202608281152C_0644090501.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T080003_V202608281152C_0644090503.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T110003_V202608281152C_0644090504.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T140003_V202608281153C_0644090505.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T170003_V202608281153C_0644090506.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T200003_V202608281154C_0644090507.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260409T230003_V202608281154C_0644090508.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260410T014503_V202608281154C_0644100501.fits',
#  '/home/ulyanov/data/solo/phi/202604/blos/phi-fdt-blos_20260410T050003_V202608281155C_0644100502.fits',
# ...

# %%
data, mu = make_map(files, correct_dr=True, sine_lat=False, minmu=0.1, maxmu=0.25, delta_lon=180)
flux = np.nanmean(data, axis=1)
#flux = np.nanmean(data * coverage, axis=1) / np.nanmean(coverage, axis=1)
# Out:
# /home/ulyanov/PycharmProjects/reprojection/src/reprojection.py:116: RuntimeWarning: invalid value encountered in divide
#   mu += np.nan_to_num((1 / alpha - mu) * weight / coverage)
# /tmp/ipykernel_148890/3318970587.py:2: RuntimeWarning: Mean of empty slice
#   flux = np.nanmean(data, axis=1)

# %%
show_map(data, vmin=-1000, vmax=1000, sine_lat=False)

# %%
show_map(mu, cmap='inferno', vmin=0, vmax=1, sine_lat=False)

# %%
nx, ny = data.shape
lat = np.arcsin(np.arange(nx) / (nx - 1) * 2 - 1) * 180 / np.pi

plt.figure(figsize=(10,8))
plt.plot(lat, flux)


plt.xlim(-90,90)
plt.ylim(-10,10)
plt.grid(True)
plt.tight_layout()

# %%
file = '/home/ulyanov/data/sdo/hmi/synoptic_maps/hmi.Synoptic_Mr_720s.2310.synopMr.fits'

with fits.open(file) as hdul:
    header = hdul[0].header.copy()
    data_ = hdul[0].data.copy()

data_ = rebin(data_, 2)
header['T_OBS']
# Out:
# '2026.04.29_07:08:43_TAI'

# %%
show_map(data_, vmin=-1000, vmax=1000, sine_lat=True)

# %%
temp = data_.copy()
temp[np.isnan(data)] = np.nan
flux_ = np.nanmean(temp, axis=1)

nx, ny = data_.shape
lat = np.arcsin(np.arange(nx) / (nx - 1) * 2 - 1) * 180 / np.pi

plt.figure(figsize=(10,8))
plt.plot(lat, flux_)
plt.plot(lat, flux)

plt.xlim(-90,90)
plt.ylim(-10,10)
plt.grid(True)
plt.tight_layout()
# Out:
# /tmp/ipykernel_133578/1164682074.py:3: RuntimeWarning: Mean of empty slice
#   flux_ = np.nanmean(temp, axis=1)
