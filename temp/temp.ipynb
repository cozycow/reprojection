# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
from utils import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
#files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*blos_202411*'))
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/202605/blos_/*'))
files
# Out:
# ['/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T020003_V202608281634C_0645010501.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T050003_V202608281635C_0645010502.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T080003_V202608281635C_0645010503.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T110003_V202608281635C_0645010504.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T140003_V202608281635C_0645010505.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T170003_V202608281635C_0645010506.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T200003_V202608281636C_0645010507.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260501T230003_V202608281636C_0645010508.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T020003_V202608281636C_0645020501.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T050003_V202608281636C_0645020502.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T080003_V202608281636C_0645020503.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T110003_V202608281636C_0645020504.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T140003_V202608281637C_0645020505.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T170003_V202608281637C_0645020506.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260502T200003_V202608281637C_0645020507.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T020003_V202608281637C_0645030501.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T050003_V202608281637C_0645030502.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T080003_V202608281637C_0645030503.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T110003_V202608281638C_0645030504.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T140003_V202608281638C_0645030505.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T170003_V202608281638C_0645030506.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260503T200003_V202608281638C_0645030507.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T020003_V202608281638C_0645040501.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T050003_V202608281639C_0645040502.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T080003_V202608281639C_0645040503.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T110003_V202608281639C_0645040504.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T140003_V202608281639C_0645040505.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T170003_V202608281639C_0645040506.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T200003_V202608281639C_0645040507.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260504T230003_V202608281640C_0645040508.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T013003_V202608281640C_0645050501.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T050003_V202608281640C_0645050502.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T080003_V202608281640C_0645050503.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T110003_V202608281640C_0645050504.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T140003_V202608281640C_0645050505.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T170003_V202608281641C_0645050506.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T200003_V202608281641C_0645050507.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260505T230003_V202608281641C_0645050508.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260506T020003_V202608281641C_0645060501.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260506T050003_V202608281641C_0645060502.fits',
#  '/home/ulyanov/data/solo/phi/202605/blos_/phi-fdt-blos_20260506T080003_V202608281641C_0645060503.fits']

# %%
data, coverage = make_map(files, correct_dr=True, sine_lat=True, mu_thr=0.1, delta_lon=10)

# %%
show_map(data, vmin=-1000, vmax=1000, sine_lat=True)

# %%
flux = np.nanmean(data, axis=1)
#flux = np.nanmean(data * coverage, axis=1) / np.nanmean(coverage, axis=1)
# Out:
# /tmp/ipykernel_58077/91772075.py:1: RuntimeWarning: Mean of empty slice
#   flux = np.nanmean(data, axis=1)

# %%
nx, ny = data.shape
lat = np.arcsin(np.arange(nx) / (nx - 1) * 2 - 1) * 180 / np.pi

plt.figure(figsize=(10,8))
plt.plot(lat, flux)

plt.xlim(-90,90)
plt.ylim(-10,10)
plt.grid(True)
plt.tight_layout()

# %%
file = '/home/ulyanov/data/sdo/hmi/synoptic_maps/hmi.Synoptic_Mr_720s.2310.synopMr.fits'

with fits.open(file) as hdul:
    header = hdul[0].header.copy()
    data_ = hdul[0].data.copy()

data_ = rebin(data_, 2)
header['T_OBS']
# Out:
# '2026.04.29_07:08:43_TAI'

# %%
show_map(data_, vmin=-1000, vmax=1000, sine_lat=True)

# %%
temp = data_.copy()
temp[np.isnan(data)] = np.nan
flux_ = np.nanmean(temp, axis=1)

nx, ny = data_.shape
lat = np.arcsin(np.arange(nx) / (nx - 1) * 2 - 1) * 180 / np.pi

plt.figure(figsize=(10,8))
plt.plot(lat, flux_)
plt.plot(lat, flux)

plt.xlim(-90,90)
plt.ylim(-10,10)
plt.grid(True)
plt.tight_layout()
# Out:
# /tmp/ipykernel_58077/1164682074.py:3: RuntimeWarning: Mean of empty slice
#   flux_ = np.nanmean(temp, axis=1)
