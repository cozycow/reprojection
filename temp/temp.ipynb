# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
from utils import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
#files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*blos_202505*'))[:20]
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/202505/blos/*'))
files
# Out:
# ['/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T002002_V202608241659C_0545010501.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T032003_V202608241700C_0545010502.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T064003_V202608241701C_0545010503.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T092003_V202608241701C_0545010504.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T122003_V202608241702C_0545010505.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T150003_V202608241703C_0545010506.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T181003_V202608241704C_0545010507.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T212003_V202608241704C_0545010508.fits',
#  '/home/ulyanov/data/solo/phi/202505/blos/phi-fdt-blos_20250501T235003_V202608241705C_0545010509.fits',
# ...

# %%
data, coverage = make_map(files, correct_dr=True, sine_lat=True, mu_thr=0.1)

# %%
show_map(data, vmin=-200, vmax=200, sine_lat=True)

# %%
nx, ny = data.shape

lat = np.arcsin(np.arange(nx) / (nx - 1) * 2 - 1) * 180 / np.pi

plt.figure(figsize=(10,8))
plt.plot(lat, np.nanmean(data, axis=1))

plt.xlim(-90,90)
plt.ylim(-10,10)
plt.grid(True)
plt.tight_layout()
# Out:
# /tmp/ipykernel_37395/4125746814.py:6: RuntimeWarning: Mean of empty slice
#   plt.plot(lat, np.nanmean(data, axis=1))

# %%
file = '/home/ulyanov/data/sdo/hmi/synoptic_maps/hmi.Synoptic_Mr_720s.2297.synopMr.fits'

with fits.open(file) as hdul:
    header = hdul[0].header.copy()
    data = hdul[0].data.copy()

data = rebin(data, 2)
