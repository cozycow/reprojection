# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/202605/blos/*'))
#files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*blos_202505*'))

# %%
data, coverage = make_map(files, polar=True, correct_dr=True, mu_thr=0.15)

# %%
show_polar_view(data, label=r'$B_{los}$, G', title='May 2026, North pole')
