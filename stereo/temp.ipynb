# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from utils import *
from interpolation import *
import pandas as pd
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/temp/*'))
files
# Out:
# ['/home/ulyanov/data/solo/phi/temp/solo_L2_phi-fdt-blos_20231211T090003_V202602181102_0352111540.fits.gz',
#  '/home/ulyanov/data/solo/phi/temp/solo_L2_phi-fdt-blos_20231211T090003_V202604081437_0352111540.fits.gz',
#  '/home/ulyanov/data/solo/phi/temp/solo_L2_phi-fdt-blos_20241108T001503_V202602181102_0451080501.fits.gz',
#  '/home/ulyanov/data/solo/phi/temp/solo_L2_phi-fdt-blos_20241108T001503_V202604081437_0451080501.fits.gz',
#  '/home/ulyanov/data/solo/phi/temp/solo_L2_phi-fdt-stokes_20241108T001503_V202604081437_0451080501.fits.gz']

# %%
file1 = files[0]
file2 = files[1]

with fits.open(file1) as hdul:
    header1 = hdul[0].header
    data1 = hdul[0].data

with fits.open(file2) as hdul:
    header2 = hdul[0].header
    data2 = hdul[0].data

# %%
plt.figure(figsize=(10,10))
plt.imshow(data1, cmap='seismic', vmin=-50, vmax=50)
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plt.imshow(data2, cmap='seismic', vmin=-50, vmax=50)
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plt.scatter(data1, data2, s=0.05)

plt.xlim(-100,100)
plt.ylim(-100,100)

plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plt.imshow(data2 - data1 / 1.3, cmap='seismic', vmin=-50, vmax=50)
plt.tight_layout()

# %%
0.36 / 0.83
# Out:
# 0.43373493975903615

# %%
file = files[-1]

with fits.open(file) as hdul:
    header = hdul[0].header
    data = hdul[0].data

# %%
plt.figure(figsize=(10,10))
plt.imshow(data[0,3])
plt.tight_layout()
