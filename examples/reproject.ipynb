# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
#from utils import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*'))

# %% [markdown]
# Reading the data

# %%
file1 = files[0]
file2 = files[1]

with fits.open(file1) as hdul:
    header1 = hdul[0].header
    data1 = hdul[0].data

with fits.open(file2) as hdul:
    header2 = hdul[0].header
    data2 = hdul[0].data

#data1 = rebin(data1, 8, update_header=header1)
#data2 = rebin(data2, 8, update_header=header2)

print(file1, file2)
# Out:
# /home/ulyanov/data/solo/phi/2024_2025/solo_L2_phi-fdt-blos_20240101T040003_V202602220902_0441010503.fits.gz /home/ulyanov/data/solo/phi/2024_2025/solo_L2_phi-fdt-blos_20240101T060007_V202602220902_0441010504.fits.gz

# %% [markdown]
# Showing the input data

# %%
show_data(data1, View.from_header(header1), vmin=-1000, vmax=1000)

# %%
show_data(data2, View.from_header(header2), vmin=-1000, vmax=1000)

# %% [markdown]
# Reading the WCS information from header into the View class and calculating the transformation from local reference frame to Carrington coordinates

# %%
view1 = View.from_header(header1)
transform1 = view1.to_carrington()

transform1
# Out:
# [Normalize(shift:(357.8501, 395.407), scale:281.88844503724215),
#  Make3d(theta:0.2796775, inv:False),
#  Rotate(axis:(0.8542891404318219, 0.47997904401484176, -0.19952489029406248), angle:0.059908982938059116)]

# %%
view2 = View.from_header(header2)
transform2 = view2.to_carrington()

transform2
# Out:
# [Normalize(shift:(358.3255, 394.6404), scale:281.8851598629294),
#  Make3d(theta:0.27966069444444447, inv:False),
#  Rotate(axis:(0.8555950382048001, 0.4811017585333418, -0.19104509555456511), angle:0.059742893512677676)]

# %% [markdown]
# Calculating the coordinate transformation from one dataset to another

# %%
transform = transform1 - transform2

transform
# Out:
# [Normalize(shift:(357.8501, 395.407), scale:281.88844503724215),
#  Make3d(theta:0.2796775, inv:False),
#  Rotate(axis:(0.8634014309897678, -0.5008705070258389, 0.06055331664326942), angle:0.00034199569470266637),
#  Make3d(theta:-0.27966069444444447, inv:True),
#  Normalize(shift:(-1.2711754679609268, -1.4000041725924819), scale:0.0035475439731778146)]

# %% [markdown]
# Reprojecting the second dataset onto the first one and showing the result

# %%
data2_ = reproject(data2, header2, header1, correct_mu=True, mu_thr=0.1)

# %%
show_data(data2_, View.from_header(header1), vmin=-1000, vmax=1000)
