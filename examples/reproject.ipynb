# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from utils import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*'))
#files = sorted(glob.glob('D:\\data\\sdo\\hmi\\nonpolar\\*'))

# %% [markdown]
# Reading the data

# %%
file1 = files[0]
file2 = files[1]

with fits.open(file1) as hdul:
    header1 = hdul[0].header
    data1 = hdul[0].data

with fits.open(file2) as hdul:
    header2 = hdul[0].header
    data2 = hdul[0].data

#data1 = rebin(data1, 8, update_header=header1)
#data2 = rebin(data2, 8, update_header=header2)

print(file1, file2)
# Out:
# /home/ulyanov/data/solo/phi/2024_2025/solo_L2_phi-fdt-blos_20240101T040003_V202602220902_0441010503.fits.gz /home/ulyanov/data/solo/phi/2024_2025/solo_L2_phi-fdt-blos_20240101T060007_V202602220902_0441010504.fits.gz

# %% [markdown]
# Showing the input data

# %%
show_data(data1, View.from_header(header1))

# %%
show_data(data2, View.from_header(header2))

# %% [markdown]
# Reading the WCS information from header into the View class and calculating the transformation from local reference frame to Carrington coordinates

# %%
view1 = View.from_header(header1)
transform1 = view1.to_carrington()

transform1
# Out:
# [Translate(shift:(-255.55053750000002, -254.49989375)),
#  Scale(factor:0.004170340297682703),
#  Expand(inv:False),
#  ToParaxial(theta:0.2685825941297743),
#  Filter(func:<function View.to_helioprojective.<locals>.<lambda> at 0x000002A0014E4C10>, inv:False),
#  Rotate(axis:(0.9856190351790909, 0.00631548140345541, 0.1688645379802422), angle:0.056141481825569946),
#  ToSpherical(inv:False)]

# %%
view2 = View.from_header(header2)
transform2 = view2.to_carrington()

transform2
# Out:
# [Translate(shift:(-255.54116875, -254.5045475)),
#  Scale(factor:0.004168844347223094),
#  Expand(inv:False),
#  ToParaxial(theta:0.2686786227756076),
#  Filter(func:<function View.to_helioprojective.<locals>.<lambda> at 0x000002A0014E5FC0>, inv:False),
#  Rotate(axis:(0.9649258967317832, 0.00969878831847001, 0.26234318615416224), angle:0.05609145527122929),
#  ToSpherical(inv:False)]

# %% [markdown]
# Calculating the coordinate transformation from one dataset to another

# %%
transform = transform1 - transform2

transform
# Out:
# [Translate(shift:(-255.55053750000002, -254.49989375)),
#  Scale(factor:0.004170340297682703),
#  Expand(inv:False),
#  ToParaxial(theta:0.2685825941297743),
#  Filter(func:<function View.to_helioprojective.<locals>.<lambda> at 0x000002A0014E4C10>, inv:False),
#  Rotate(axis:(0.00685356258234171, -0.9971317579401957, 0.07537430588088068), angle:0.0033434848304526583),
#  Filter(func:<function View.to_helioprojective.<locals>.<lambda> at 0x000002A0014E5FC0>, inv:True),
#  ToParaxial(theta:-0.2686786227756076),
#  Expand(inv:True),
#  Scale(factor:239.8746311231575),
#  Translate(shift:(255.54116875, 254.5045475))]

# %% [markdown]
# Reprojecting the second dataset onto the first one and showing the result

# %%
data2_ = reproject(data2, header2, header1, correct_mu=True, mu_thr=0.1)

# %%
show_data(data2_, header1)

# %%
show_data(data2_ - data1, header1)
