# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*'))

# %%
data, coverage = make_map(files[100:200], polar=True, correct_dr=True)

# %%
show_polar_view(data)
# Out:
# /home/ulyanov/PycharmProjects/reprojection/src/transforms.py:149: RuntimeWarning: divide by zero encountered in divide
#   return (y, x), alpha / z
