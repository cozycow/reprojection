# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*'))

# %% [markdown]
# Mapping and showing the data in spherical coordinates

# %%
map, coverage = make_map(files[200:300], dlat=1 / 359.5, dlon=0.2, correct_mu=True, mu_thr=0.1, correct_dr=True, sine_lat=True)

# %%
show_map(map, vmin=-100, vmax=100, sine_lat=True)
