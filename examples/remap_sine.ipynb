# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/2024_2025/*'))

# %% [markdown]
# Reading and showing the data

# %%
file = files[50]

with fits.open(file) as hdul:
    header = hdul[0].header
    data = hdul[0].data

# %%
show_data(data, View.from_header(header), vmin=-1000, vmax=1000)

# %% [markdown]
# Mapping and showing the data in spherical coordinates

# %%
data_ = remap(data, header, dlat=1 / 359.5, correct_dr=True, sine_lat=True)

# %%
show_map(data_, vmin=-100, vmax=100, sine_lat=True)

nx, ny = data_.shape
nx, ny
# Out:
# (720, 1800)
