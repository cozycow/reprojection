# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/202604_/blos/*'))

# %%
data, alpha = make_map(files, polar=True, correct_dr=True, correct_bias=True, minmu=0.1, delta_lon=180, binning=1, lam=0.5)
# Out:
# /home/ulyanov/PycharmProjects/reprojection/src/transforms.py:131: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(1 - x ** 2 - y ** 2)
# /home/ulyanov/PycharmProjects/reprojection/src/reprojection.py:123: RuntimeWarning: invalid value encountered in divide
#   mean_alpha += np.nan_to_num((alpha - mean_alpha) * weight / coverage)
# /home/ulyanov/PycharmProjects/reprojection/src/reprojection.py:129: RuntimeWarning: invalid value encountered in divide
#   var_alpha /= coverage
# /home/ulyanov/PycharmProjects/reprojection/src/reprojection.py:130: RuntimeWarning: invalid value encountered in divide
#   cov_data_alpha /= coverage

# %%
show_polar_view(data, vmin=-100, vmax=100)
# Out:
# /home/ulyanov/PycharmProjects/reprojection/src/transforms.py:151: RuntimeWarning: divide by zero encountered in divide
#   return (y, x), alpha / z
