# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from reprojection import *
from show import *
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
files = sorted(glob.glob('/home/ulyanov/data/solo/phi/202604_/blos/*'))

# %%
data, alpha = make_map(files, polar=True, correct_dr=True, correct_bias=True, minmu=0.1, delta_lon=90, binning=1, lam=0.05)

# %%
show_polar_view(data, vmin=-200, vmax=200)
